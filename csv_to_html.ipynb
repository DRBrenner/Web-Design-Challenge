# %%
import pandas as pd

# %%
# Reference the file where the CSV is located
cities_csv = "resources/cities.csv"

# Import the data into a Pandas DataFrame
cities_df = pd.read_csv(cities_csv, index_col=[0])
cities_df
# Out:
#                           City Country    Lat     Lng          Date  Max_Temp  \
# 0                       cortez      US  37.35 -108.58  1.564121e+09     70.00
# 1                       avarua      CK -21.21 -159.78  1.564121e+09     71.60
# 2                      ivanava      BY  52.14   25.53  1.564121e+09     60.97
# 3                      ahipara      NZ -35.17  173.16  1.564121e+09     55.00
# 4                         lebu      ET   8.96   38.73  1.564121e+09     57.20
# ..                         ...     ...    ...     ...           ...       ...
# 604              cockburn town      TC  21.46  -71.14  1.564121e+09     82.57
# 605                      merta      IN  26.65   74.03  1.564121e+09     88.87
# 606                   plouzane      FR  48.38   -4.62  1.564121e+09     64.40
# 607                     powell      US  40.16  -83.08  1.564121e+09     64.00
# 608  san bartolome de tirajana     NaN    NaN     NaN           NaN       NaN
#
#      Humidity  Cloudiness  Wind_Speed
# 0        68.0         1.0       10.13
# 1        83.0       100.0        3.36
# 2        88.0        95.0        7.23
# 3       100.0        79.0       10.60
# 4        93.0        75.0        6.93
# ..        ...         ...         ...
# 604      78.0        33.0       19.91
# 605      54.0       100.0       14.47
# 606      88.0        75.0        4.70
# 607      88.0         1.0        2.86
# 608       NaN         NaN         NaN
#
# [609 rows x 9 columns]

# %%
cities_html = cities_df.to_html("cities_table.html")

# %%
print(cities_html)
# Out:
# None
